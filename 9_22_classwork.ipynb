# %% [markdown]
# <a href="https://colab.research.google.com/github/leslyveizaga/ds1002-hwk8kc/blob/main/9_22_classwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get head row - whatever number I want
mock_data.head(3)
# Out:
#    id first_name last_name                     email  gender  age
# 0   1        Joe      Byas       jbyas0@sakura.ne.jp    Male   61
# 1   2        Kai      Lord         klord1@hao123.com  Female   16
# 2   3    Caddric    Gaymer  cgaymer2@squarespace.com    Male   72

# %%
mock_data.tail()
# Out:
#        id first_name   last_name                  email      gender  age
# 995   996       Yank     Folling        yfollingrn@t.co  Non-binary   50
# 996   997      Reina  Leftbridge  rleftbridgero@cmu.edu      Female   51
# 997   998     Gareth      Mathan    gmathanrp@wufoo.com        Male   63
# 998   999  Sutherlan      Saylor    ssaylorrq@fotki.com        Male   13
# 999  1000       Luce      Pascoe       lpascoerr@go.com        Male   70

# %%
# grab specific data form a df
mock_data.loc[9]
# Out:
# id                               10
# first_name                  Lindsey
# last_name                   Cettell
# email         lcettell9@comsenz.com
# gender                         Male
# age                              65
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    46.005000
# std     288.819436    26.785826
# min       1.000000     1.000000
# 25%     250.750000    22.000000
# 50%     500.500000    48.000000
# 75%     750.250000    70.000000
# max    1000.000000    90.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
#what data types are in this df?
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id     fname    lname                     email  gender  age
# 0   1       Joe     Byas       jbyas0@sakura.ne.jp    Male   61
# 1   2       Kai     Lord         klord1@hao123.com  Female   16
# 2   3   Caddric   Gaymer  cgaymer2@squarespace.com    Male   72
# 3   4  Stephine  Purches         spurches3@cdc.gov  Female   48
# 4   5     Lorne    Blodg     lblodg4@wordpress.com    Male   38

# %%
mock_data['fname']
# Out:
# 0            Joe
# 1            Kai
# 2        Caddric
# 3       Stephine
# 4          Lorne
#          ...
# 995         Yank
# 996        Reina
# 997       Gareth
# 998    Sutherlan
# 999         Luce
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0            Joe
# 1            Kai
# 2        Caddric
# 3       Stephine
# 4          Lorne
#          ...
# 995         Yank
# 996        Reina
# 997       Gareth
# 998    Sutherlan
# 999         Luce
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#          fname       lname
# 0          Joe        Byas
# 1          Kai        Lord
# 2      Caddric      Gaymer
# 3     Stephine     Purches
# 4        Lorne       Blodg
# ..         ...         ...
# 995       Yank     Folling
# 996      Reina  Leftbridge
# 997     Gareth      Mathan
# 998  Sutherlan      Saylor
# 999       Luce      Pascoe
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        33.000000
# Bigender       52.000000
# Female         46.546911
# Genderfluid    52.647059
# Genderqueer    46.562500
# Male           45.738298
# Non-binary     42.350000
# Polygender     44.750000
# Name: age, dtype: float64
